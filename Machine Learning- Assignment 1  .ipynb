# %% [markdown]
# Numpy library used

# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

# %% [markdown]
# Data imported in data frame named as df_CG

# %%
df_CG = pd.read_csv('C:/Users/themr/Desktop/1181/Machine Learning/1/Cigar.csv')
df_CG
# Out:
#       state  year  price     pop   pop16    cpi           ndi  sales  pimin
# 0         1    63   28.6  3383.0  2236.5   30.6   1558.304530   93.9   26.1
# 1         1    64   29.8  3431.0  2276.7   31.0   1684.073203   95.4   27.5
# 2         1    65   29.8  3486.0  2327.5   31.5   1809.841875   98.5   28.9
# 3         1    66   31.5  3524.0  2369.7   32.4   1915.160357   96.4   29.5
# 4         1    67   31.6  3533.0  2393.7   33.4   2023.546368   95.5   29.6
# 5         1    68   35.6  3522.0  2405.2   34.8   2202.485536   88.4   32.0
# 6         1    69   36.6  3531.0  2411.9   36.7   2377.334667   90.1   32.8
# 7         1    70   39.6  3444.0  2394.6   38.8   2591.039159   89.8   34.3
# 8         1    71   42.7  3481.0  2443.5   40.5   2785.315971   95.4   35.8
# 9         1    72   42.3  3511.0  2484.7   41.8   3034.808297  101.1   37.4
# 10        1    73   42.1  3540.0  2526.0   44.4   3387.574086  102.9   37.3
# ...

# %%
plt.hist(df_CG.price,bins=50)
# Out:
# (array([ 68., 143., 110.,  68.,  99.,  79.,  64.,  52.,  56.,  48.,  45.,
#          36.,  30.,  15.,  13.,  15.,  18.,  12.,  23.,  20.,  22.,  29.,
#          30.,  15.,  18.,  27.,  14.,  24.,  13.,  15.,  15.,  15.,  12.,
#          20.,  11.,  14.,   9.,   4.,   8.,   7.,   8.,   5.,  10.,   7.,
#           0.,   5.,   3.,   2.,   1.,   3.]),
#  array([ 23.4 ,  26.97,  30.54,  34.11,  37.68,  41.25,  44.82,  48.39,
#          51.96,  55.53,  59.1 ,  62.67,  66.24,  69.81,  73.38,  76.95,
#          80.52,  84.09,  87.66,  91.23,  94.8 ,  98.37, 101.94, 105.51,
#         109.08, 112.65, 116.22, 119.79, 123.36, 126.93, 130.5 , 134.07,
#         137.64, 141.21, 144.78, 148.35, 151.92, 155.49, 159.06, 162.63,
#         166.2 , 169.77, 173.34, 176.91, 180.48, 184.05, 187.62, 191.19,
#         194.76, 198.33, 201.9 ]),
#  <a list of 50 Patch objects>)

# %%
plt.scatter(df_CG.state,df_CG.price)
#label
plt.ylabel('Price')
plt.xlabel('State')
# Out:
# Text(0.5,0,'State')

# %%
plt.scatter(df_CG.year,df_CG.price)

#label
plt.ylabel('Price')
plt.xlabel('Year')
# Out:
# Text(0.5,0,'Year')

# %%
plt.scatter(df_CG.pop,df_CG.price)

#label
plt.ylabel('Price')
plt.xlabel('Pop16')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-e67f7d15b229> in <module>()
# ----> 1 A = plt.scatter(df_CG.pop,df_CG.price)
#       2 autoscale(A)
#       3 #label
#       4 plt.ylabel('Price')
#       5 plt.xlabel('Pop16')
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3376                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3377                          linewidths=linewidths, verts=verts,
# -> 3378                          edgecolors=edgecolors, data=data, **kwargs)
#    3379     finally:
#    3380         ax._hold = washold
#
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
plt.scatter(df_CG.pop16,df_CG.price)
#label
plt.ylabel('Price')
plt.xlabel('Pop16')
# Out:
# Text(0.5,0,'Pop16')

# %%
plt.scatter(df_CG.cpi,df_CG.price)

# %%
plt.scatter(df_CG.ndi,df_CG.price)

# %%
plt.scatter(df_CG.sales,df_CG.price)

# %%
plt.scatter(df_CG.pimin,df_CG.price)

# %%
df_CG.corr()
# Out:
#               state          year     price       pop     pop16           cpi  \
# state  1.000000e+00  5.917743e-18 -0.009617 -0.093681 -0.096155 -3.054743e-17
# year   5.917743e-18  1.000000e+00  0.918218  0.082145  0.117880  9.794833e-01
# price -9.616899e-03  9.182177e-01  1.000000  0.107727  0.137026  9.491390e-01
# pop   -9.368120e-02  8.214504e-02  0.107727  1.000000  0.997799  8.153477e-02
# pop16 -9.615511e-02  1.178804e-01  0.137026  0.997799  1.000000  1.152144e-01
# cpi   -3.054743e-17  9.794833e-01  0.949139  0.081535  0.115214  1.000000e+00
# ndi   -3.553248e-02  9.355700e-01  0.944311  0.158933  0.193687  9.532968e-01
# sales -1.035661e-01 -1.819010e-01 -0.311258 -0.111541 -0.111596 -2.102311e-01
# pimin -7.837030e-05  9.202965e-01  0.987050  0.077434  0.106264  9.527587e-01
#
#             ndi     sales     pimin
# state -0.035532 -0.103566 -0.000078
# year   0.935570 -0.181901  0.920296
# price  0.944311 -0.311258  0.987050
# pop    0.158933 -0.111541  0.077434
# ...
